# %% [markdown]
# <font size="10">Rahamat Sekh</font>

# %% [markdown]
# <font size="5">Task-1 (GRIPMAR24)</font>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
url = "http://bit.ly/w-data"
df = pd.read_csv(url)
df
# Out:
#     Hours  Scores
# 0     2.5      21
# 1     5.1      47
# 2     3.2      27
# 3     8.5      75
# 4     3.5      30
# 5     1.5      20
# 6     9.2      88
# 7     5.5      60
# 8     8.3      81
# 9     2.7      25
# 10    7.7      85
# 11    5.9      62
# 12    4.5      41
# 13    3.3      42
# 14    1.1      17
# 15    8.9      95
# 16    2.5      30
# 17    1.9      24
# 18    6.1      67
# 19    7.4      69
# 20    2.7      30
# 21    4.8      54
# 22    3.8      35
# 23    6.9      76
# 24    7.8      86

# %%
df.plot(x= 'Hours', y= 'Scores', style= 'o', color= 'Red', grid= True)
plt.title('Hours v Scores')
plt.xlabel('(Hours studied)')
plt.ylabel('(Percentage scored)')
plt.show()

# %%
X = df['Hours'].values.reshape(-1,1)
y = df['Scores'].values

# %%
from sklearn.model_selection import train_test_split  
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
plt.scatter(X.mean(), y.mean(), color= 'red')
plt.scatter(df['Hours'], df['Scores'])
plt.title('Hours v Scores')
plt.xlabel('(Hours studied)')
plt.ylabel('(Percentage scored)')
plt.show()

# %%
line = reg.coef_*X+reg.intercept_
plt.scatter(X, y)
plt.plot(X, line)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
m = reg.coef_
m
# Out:
# array([9.91065648])

# %%
c = reg.intercept_
c
# Out:
# 2.018160041434662

# %%
y_pred = reg.predict(X_test) 
d_f = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})  
d_f
# Out:
#    Actual  Predicted
# 0      20  16.884145
# 1      27  33.732261
# 2      69  75.357018
# 3      30  26.794801
# 4      62  60.491033

# %%
y = 9.91*9.25 + 2.02 
print("If a student studies for 9.25 hours/day, the predicted score will be {}".format(y))
# Out:
# If a student studies for 9.25 hours/day, the predicted score will be 93.6875

# %%
from sklearn import metrics
print('Mean absolute error: ', metrics.mean_absolute_error(y_test, y_pred))
# Out:
# Mean absolute error:  4.183859899002982
